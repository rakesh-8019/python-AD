# %% [markdown]
# ## 1) mention about problem statement
# ## 2) talk about columns
# ## 3)install the models and required libraries
# ## 4)Load data set
# ## 5)understand your data
# ## 6)EDA
# ## i)univariate analysis
# ##  ii)Bi-variate analysis
# ##  iii)Multivarivate analysis
# ## 7)check the null-values or missing values
# ## i)treating the null values(fill with mean or median or mode)
# ## ii)drop null values if they are less than 5%-10%
# ## 8)check the duplicates
# ## i)drop duplicates
# ## 9)treating the ouliers
# ## i)check the outliers
# ## ii)remove outliers
# ## iii)make the box plot before and after the outliers
# ## 10)Feature engineering
# ## a)i)extract the features
# ##  ii)create the features
# ##  iii)select the features
# ## b)checking the multicoliniarity
# ## i)heat map
# ## ii)vif technique
# ## c)transformation
# ## i)one hot encoding or label encoding
# ## d)scaling(min_max_scalar)
# ## 11)X-y features split
# ## 12)train test split

# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv(r"C:\Users\rkaku\Documents\Mushroom_Dataset.csv")

# %%
data
# Out:
#        class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0          e         c           g         y       f    m               f
# 1          p         c           y         u       t    y               f
# 2          e         s           f         u       t    l               a
# 3          e         k           f         e       f    p               a
# 4          p         k           g         n       f    a               f
# ...      ...       ...         ...       ...     ...  ...             ...
# 100995     e         k           f         p       t    y               f
# 100996     e         s           s         n       f    a               f
# 100997     p         b           f         n       f    n               f
# 100998     e         x           s         y       t    l               a
# 100999     e         b           f         b       t    c               a
#
#        gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 0                 w         b          r  ...                        s
# 1                 c         b          k  ...                        s
# 2                 c         n          e  ...                        k
# 3                 c         b          k  ...                        y
# 4                 c         n          p  ...                        k
# ...             ...       ...        ...  ...                      ...
# 100995            w         n          n  ...                        f
# 100996            c         n          n  ...                        f
# 100997            c         n          o  ...                        k
# 100998            w         b          k  ...                        s
# 100999            c         b          o  ...                        k
#
#        stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                           o                      o         p          y
# 1                           w                      w         p          n
# 2                           b                      p         p          y
# 3                           b                      n         p          w
# 4                           y                      c         p          n
# ...                       ...                    ...       ...        ...
# 100995                      n                      n         p          o
# 100996                      w                      b         p          n
# 100997                      c                      w         p          n
# 100998                      o                      p         p          y
# 100999                      y                      c         p          o
#
#        ring-number ring-type spore-print-color population habitat
# 0                n         e                 y          v       g
# 1                n         l                 b          a       u
# 2                t         l                 n          c       w
# 3                t         l                 w          c       p
# 4                n         p                 o          s       g
# ...            ...       ...               ...        ...     ...
# 100995           t         e                 n          s       m
# 100996           t         l                 u          n       p
# 100997           n         l                 w          s       d
# 100998           o         p                 y          a       d
# 100999           t         e                 r          c       p
#
# [101000 rows x 23 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101000 entries, 0 to 100999
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   class                     101000 non-null  object
#  1   cap-shape                 101000 non-null  object
#  2   cap-surface               101000 non-null  object
#  3   cap-color                 101000 non-null  object
#  4   bruises                   101000 non-null  object
#  5   odor                      101000 non-null  object
#  6   gill-attachment           101000 non-null  object
#  7   gill-spacing              101000 non-null  object
#  8   gill-size                 101000 non-null  object
#  9   gill-color                101000 non-null  object
#  10  stalk-shape               101000 non-null  object
#  11  stalk-root                101000 non-null  object
#  12  stalk-surface-above-ring  101000 non-null  object
#  13  stalk-surface-below-ring  101000 non-null  object
#  14  stalk-color-above-ring    101000 non-null  object
#  15  stalk-color-below-ring    101000 non-null  object
#  16  veil-type                 101000 non-null  object
#  17  veil-color                101000 non-null  object
#  18  ring-number               101000 non-null  object
#  19  ring-type                 101000 non-null  object
#  20  spore-print-color         101000 non-null  object
#  21  population                101000 non-null  object
#  22  habitat                   101000 non-null  object
# dtypes: object(23)
# memory usage: 17.7+ MB

# %% [markdown]
# data.isnull().sum

# %%
data.isnull()
# Out:
#         class  cap-shape  cap-surface  cap-color  bruises   odor  \
# 0       False      False        False      False    False  False
# 1       False      False        False      False    False  False
# 2       False      False        False      False    False  False
# 3       False      False        False      False    False  False
# 4       False      False        False      False    False  False
# ...       ...        ...          ...        ...      ...    ...
# 100995  False      False        False      False    False  False
# 100996  False      False        False      False    False  False
# 100997  False      False        False      False    False  False
# 100998  False      False        False      False    False  False
# 100999  False      False        False      False    False  False
#
#         gill-attachment  gill-spacing  gill-size  gill-color  ...  \
# 0                 False         False      False       False  ...
# 1                 False         False      False       False  ...
# 2                 False         False      False       False  ...
# 3                 False         False      False       False  ...
# 4                 False         False      False       False  ...
# ...                 ...           ...        ...         ...  ...
# 100995            False         False      False       False  ...
# 100996            False         False      False       False  ...
# 100997            False         False      False       False  ...
# 100998            False         False      False       False  ...
# 100999            False         False      False       False  ...
#
#         stalk-surface-below-ring  stalk-color-above-ring  \
# 0                          False                   False
# 1                          False                   False
# 2                          False                   False
# 3                          False                   False
# 4                          False                   False
# ...                          ...                     ...
# 100995                     False                   False
# 100996                     False                   False
# 100997                     False                   False
# 100998                     False                   False
# 100999                     False                   False
#
#         stalk-color-below-ring  veil-type  veil-color  ring-number  ring-type  \
# 0                        False      False       False        False      False
# 1                        False      False       False        False      False
# 2                        False      False       False        False      False
# 3                        False      False       False        False      False
# 4                        False      False       False        False      False
# ...                        ...        ...         ...          ...        ...
# 100995                   False      False       False        False      False
# 100996                   False      False       False        False      False
# 100997                   False      False       False        False      False
# 100998                   False      False       False        False      False
# 100999                   False      False       False        False      False
#
#         spore-print-color  population  habitat
# 0                   False       False    False
# 1                   False       False    False
# 2                   False       False    False
# 3                   False       False    False
# 4                   False       False    False
# ...                   ...         ...      ...
# 100995              False       False    False
# 100996              False       False    False
# 100997              False       False    False
# 100998              False       False    False
# 100999              False       False    False
#
# [101000 rows x 23 columns]

# %%
data.sum()
# Out:
# class                       epeepeppeeppeeeepppppeeepeepeeeepppeepepeeeepe...
# cap-shape                   ccskkfkxfkxxkkckcccfbbkssskfxccbbfxfccbckbsxkf...
# cap-surface                 gyffgsgssgyfssgyygsyfsfsfgsfsfyfyggfsfffgsgsgf...
# cap-color                   yuuenegewnygwnnebpcwwgyrcbeyepnpnercwpuuuwrcep...
# bruises                     fttfftfttttfttttttffftftftffttftfffffttftfftft...
# odor                        mylpacfsaaslcanpapffalfamcannpysacanpyafcmsmmc...
# gill-attachment             ffaaffaafaaaafaafaaffafaffafaffaaffafaaaaaaaaf...
# gill-spacing                wccccwcccwwcwcccccwwccwwcwwcwccwcwcccccwcwwcwc...
# gill-size                   bbnbnnnbnbnnbbbbbnnnnbbbbbnbnnbnnnnnnnbbbbbnbb...
# gill-color                  rkekprkhwuukunugyyuenogorbbkkhoeorbggyyooepken...
# stalk-shape                 tttttteteeeetettttteetetteeteeteeetteeettteett...
# stalk-root                  rebcbe?e?crr??rrcb?rcc?ccbercbcrrbe?e?r?cerrcr...
# stalk-surface-above-ring    skskfssffyfksfffskyskyskffsfsfsyysykkkfsskkykf...
# stalk-surface-below-ring    sskykkfkkkyfffkffskfskyffffskkkfkfffsskyyffyks...
# stalk-color-above-ring      owbbyynywopbpnggcygcwpbbwcynygpybwyoobennppwcy...
# stalk-color-below-ring      owpncbcpobppgbyweogcwywwenpcbyeggcgwnewyycgcwe...
# veil-type                   pppppppppppppppppppppppppppppppppppppppppppppp...
# veil-color                  ynywnowwynooonoywynownoyoyonoownywnnyoyywwyony...
# ring-number                 nnttnotottnnoootntnooottnntnotnntnnonnooonooto...
# ring-type                   elllpnflppneplppfenppfnlnelflffefplplnnleplepf...
# spore-print-color           ybnworryyoubrwhwryoyuhhohruuwbyubnwhoyonkkwkwh...
# population                  vaccssvsannnaayysyncancccssvyacnsysnscvvvnysvn...
# habitat                     guwpgpwgpllgwmwumpupdlggmlmgwdlggdmpgugwumdlwg...
# dtype: object

# %%
data.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 100995    False
# 100996    False
# 100997    False
# 100998    False
# 100999    False
# Length: 101000, dtype: bool

# %%
data.describe().T.style.background_gradient(cmap='rainbow')
# Out:
# <style type="text/css">
# </style>
# <table id="T_5cf69">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5cf69_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_5cf69_level0_col1" class="col_heading level0 col1" >unique</th>
#       <th id="T_5cf69_level0_col2" class="col_heading level0 col2" >top</th>
#       <th id="T_5cf69_level0_col3" class="col_heading level0 col3" >freq</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5cf69_level0_row0" class="row_heading level0 row0" >class</th>
#       <td id="T_5cf69_row0_col0" class="data row0 col0" >101000</td>
#       <td id="T_5cf69_row0_col1" class="data row0 col1" >2</td>
#       <td id="T_5cf69_row0_col2" class="data row0 col2" >p</td>
#       <td id="T_5cf69_row0_col3" class="data row0 col3" >50514</td>
#     </tr>
#     <tr>
#       <th id="T_5cf69_level0_row1" class="row_heading level0 row1" >cap-shape</th>
#       <td id="T_5cf69_row1_col0" class="data row1 col0" >101000</td>
#       <td id="T_5cf69_row1_col1" class="data row1 col1" >6</td>
#       <td id="T_5cf69_row1_col2" class="data row1 col2" >f</td>
#       <td id="T_5cf69_row1_col3" class="data row1 col3" >17042</td>
#     </tr>
#     <tr>
#       <th id="T_5cf69_level0_row2" class="row_heading level0 row2" >cap-surface</th>
#       <td id="T_5cf69_row2_col0" class="data row2 col0" >101000</td>
#       <td id="T_5cf69_row2_col1" class="data row2 col1" >4</td>
#       <td id="T_5cf69_row2_col2" class="data row2 col2" >y</td>
#       <td id="T_5cf69_row2_col3" class="data row2 col3" >25422</td>
#     </tr>
#     <tr>
#       <th id="T_5cf69_level0_row3" class="row_heading level0 row3" >cap-color</th>
#       <td id="T_5cf69_row3_col0" class="data row3 col0" >101000</td>
#       <td id="T_5cf69_row3_col1" class="data row3 col1" >10</td>
#       <td id="T_5cf69_row3_col2" class="data row3 col2" >w</td>
#       <td id="T_5cf69_row3_col3" class="data row3 col3" >10246</td>
#     </tr>
#     <tr>
#       <th id="T_5cf69_level0_row4" class="row_heading level0 row4" >bruises</th>
#       <td id="T_5cf69_row4_col0" class="data row4 col0" >101000</td>
#       <td id="T_5cf69_row4_col1" class="data row4 col1" >2</td>
#       <td id="T_5cf69_row4_col2" class="data row4 col2" >f</td>
#       <td id="T_5cf69_row4_col3" class="data row4 col3" >50590</td>
#     </tr>
#     <tr>
#       <th id="T_5cf69_level0_row5" class="row_heading level0 row5" >odor</th>
#       <td id="T_5cf69_row5_col0" class="data row5 col0" >101000</td>
#       <td id="T_5cf69_row5_col1" class="data row5 col1" >9</td>
#       <td id="T_5cf69_row5_col2" class="data row5 col2" >m</td>
#       <td id="T_5cf69_row5_col3" class="data row5 col3" >11312</td>
#     </tr>
#     <tr>
#       <th id="T_5cf69_level0_row6" class="row_heading level0 row6" >gill-attachment</th>
#       <td id="T_5cf69_row6_col0" class="data row6 col0" >101000</td>
#       <td id="T_5cf69_row6_col1" class="data row6 col1" >2</td>
#       <td id="T_5cf69_row6_col2" class="data row6 col2" >a</td>
#       <td id="T_5cf69_row6_col3" class="data row6 col3" >50515</td>
#     </tr>
#     <tr>
#       <th id="T_5cf69_level0_row7" class="row_heading level0 row7" >gill-spacing</th>
#       <td id="T_5cf69_row7_col0" class="data row7 col0" >101000</td>
#       <td id="T_5cf69_row7_col1" class="data row7 col1" >2</td>
#       <td id="T_5cf69_row7_col2" class="data row7 col2" >c</td>
#       <td id="T_5cf69_row7_col3" class="data row7 col3" >50835</td>
#     </tr>
#     <tr>
#       <th id="T_5cf69_level0_row8" class="row_heading level0 row8" >gill-size</th>
#       <td id="T_5cf69_row8_col0" class="data row8 col0" >101000</td>
#       <td id="T_5cf69_row8_col1" class="data row8 col1" >2</td>
#       <td id="T_5cf69_row8_col2" class="data row8 col2" >b</td>
#       <td id="T_5cf69_row8_col3" class="data row8 col3" >50705</td>
#     </tr>
#     <tr>
#       <th id="T_5cf69_level0_row9" class="row_heading level0 row9" >gill-color</th>
#       <td id="T_5cf69_row9_col0" class="data row9 col0" >101000</td>
#       <td id="T_5cf69_row9_col1" class="data row9 col1" >12</td>
#       <td id="T_5cf69_row9_col2" class="data row9 col2" >g</td>
#       <td id="T_5cf69_row9_col3" class="data row9 col3" >8596</td>
#     </tr>
#     <tr>
#       <th id="T_5cf69_level0_row10" class="row_heading level0 row10" >stalk-shape</th>
#       <td id="T_5cf69_row10_col0" class="data row10 col0" >101000</td>
#       <td id="T_5cf69_row10_col1" class="data row10 col1" >2</td>
#       <td id="T_5cf69_row10_col2" class="data row10 col2" >e</td>
#       <td id="T_5cf69_row10_col3" class="data row10 col3" >50532</td>
#     </tr>
#     <tr>
#       <th id="T_5cf69_level0_row11" class="row_heading level0 row11" >stalk-root</th>
#       <td id="T_5cf69_row11_col0" class="data row11 col0" >101000</td>
#       <td id="T_5cf69_row11_col1" class="data row11 col1" >5</td>
#       <td id="T_5cf69_row11_col2" class="data row11 col2" >e</td>
#       <td id="T_5cf69_row11_col3" class="data row11 col3" >20458</td>
#     </tr>
#     <tr>
#       <th id="T_5cf69_level0_row12" class="row_heading level0 row12" >stalk-surface-above-ring</th>
#       <td id="T_5cf69_row12_col0" class="data row12 col0" >101000</td>
#       <td id="T_5cf69_row12_col1" class="data row12 col1" >4</td>
#       <td id="T_5cf69_row12_col2" class="data row12 col2" >k</td>
#       <td id="T_5cf69_row12_col3" class="data row12 col3" >25275</td>
#     </tr>
#     <tr>
#       <th id="T_5cf69_level0_row13" class="row_heading level0 row13" >stalk-surface-below-ring</th>
#       <td id="T_5cf69_row13_col0" class="data row13 col0" >101000</td>
#       <td id="T_5cf69_row13_col1" class="data row13 col1" >4</td>
#       <td id="T_5cf69_row13_col2" class="data row13 col2" >k</td>
#       <td id="T_5cf69_row13_col3" class="data row13 col3" >25312</td>
#     </tr>
#     <tr>
#       <th id="T_5cf69_level0_row14" class="row_heading level0 row14" >stalk-color-above-ring</th>
#       <td id="T_5cf69_row14_col0" class="data row14 col0" >101000</td>
#       <td id="T_5cf69_row14_col1" class="data row14 col1" >9</td>
#       <td id="T_5cf69_row14_col2" class="data row14 col2" >w</td>
#       <td id="T_5cf69_row14_col3" class="data row14 col3" >11471</td>
#     </tr>
#     <tr>
#       <th id="T_5cf69_level0_row15" class="row_heading level0 row15" >stalk-color-below-ring</th>
#       <td id="T_5cf69_row15_col0" class="data row15 col0" >101000</td>
#       <td id="T_5cf69_row15_col1" class="data row15 col1" >9</td>
#       <td id="T_5cf69_row15_col2" class="data row15 col2" >p</td>
#       <td id="T_5cf69_row15_col3" class="data row15 col3" >11426</td>
#     </tr>
#     <tr>
#       <th id="T_5cf69_level0_row16" class="row_heading level0 row16" >veil-type</th>
#       <td id="T_5cf69_row16_col0" class="data row16 col0" >101000</td>
#       <td id="T_5cf69_row16_col1" class="data row16 col1" >1</td>
#       <td id="T_5cf69_row16_col2" class="data row16 col2" >p</td>
#       <td id="T_5cf69_row16_col3" class="data row16 col3" >101000</td>
#     </tr>
#     <tr>
#       <th id="T_5cf69_level0_row17" class="row_heading level0 row17" >veil-color</th>
#       <td id="T_5cf69_row17_col0" class="data row17 col0" >101000</td>
#       <td id="T_5cf69_row17_col1" class="data row17 col1" >4</td>
#       <td id="T_5cf69_row17_col2" class="data row17 col2" >o</td>
#       <td id="T_5cf69_row17_col3" class="data row17 col3" >25541</td>
#     </tr>
#     <tr>
#       <th id="T_5cf69_level0_row18" class="row_heading level0 row18" >ring-number</th>
#       <td id="T_5cf69_row18_col0" class="data row18 col0" >101000</td>
#       <td id="T_5cf69_row18_col1" class="data row18 col1" >3</td>
#       <td id="T_5cf69_row18_col2" class="data row18 col2" >t</td>
#       <td id="T_5cf69_row18_col3" class="data row18 col3" >33709</td>
#     </tr>
#     <tr>
#       <th id="T_5cf69_level0_row19" class="row_heading level0 row19" >ring-type</th>
#       <td id="T_5cf69_row19_col0" class="data row19 col0" >101000</td>
#       <td id="T_5cf69_row19_col1" class="data row19 col1" >5</td>
#       <td id="T_5cf69_row19_col2" class="data row19 col2" >l</td>
#       <td id="T_5cf69_row19_col3" class="data row19 col3" >20305</td>
#     </tr>
#     <tr>
#       <th id="T_5cf69_le

# %%
data.shape
# Out:
# (101000, 23)

# %%
data=data.astype('category')

# %%
data.dtypes
# Out:
# class                       category
# cap-shape                   category
# cap-surface                 category
# cap-color                   category
# bruises                     category
# odor                        category
# gill-attachment             category
# gill-spacing                category
# gill-size                   category
# gill-color                  category
# stalk-shape                 category
# stalk-root                  category
# stalk-surface-above-ring    category
# stalk-surface-below-ring    category
# stalk-color-above-ring      category
# stalk-color-below-ring      category
# veil-type                   category
# veil-color                  category
# ring-number                 category
# ring-type                   category
# spore-print-color           category
# population                  category
# habitat                     category
# dtype: object

# %% [markdown]
# ### for classification
# 1) logistic Regression
# 2) decision tree
# 3) random tree
# 4) gradient boost
# 5) ada boost
# 6) knm
# 7) svm
# 8) naive bayes

# %% [raw]
# 3)Hyper parameter tuning
# i)cross validation

# %%
4) deploy the best model in streamlit or flask
1) apply models
2) linear models
3) random forest
4) gradient boost
5) knm
6) svm
